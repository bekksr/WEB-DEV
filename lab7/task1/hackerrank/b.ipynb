# %% [markdown]
# ![Снимок экрана 2026-03-16 в 23.11.45.png](<attachment:Снимок экрана 2026-03-16 в 23.11.45.png>)

# %%
def split_and_join(line):
    return "-".join(line.split(" "))



if __name__ == '__main__':
    line = input()
    result = split_and_join(line)
    print(result)
